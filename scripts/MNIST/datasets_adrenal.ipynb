# %%
import pathlib
import medmnist

import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader

# %%
def show(imgs):
    plt.figure(figsize=(16, 10))
    for i, image in enumerate(imgs):
        plt.subplot(4, int(len(imgs) // 4), i + 1)
        npimg = image.numpy()
        plt.imshow(npimg, interpolation='nearest')
        plt.title(f"TS {i}")
        plt.xticks([])
        plt.yticks([])

train_data = medmnist.AdrenalMNIST3D(split="train", download=False)
train_dataloader = DataLoader(train_data, batch_size=4, shuffle=False)

# Display image and label.
train_features, train_labels = next(iter(train_dataloader), 100)
print(f"Feature batch shape: {train_features.size()}")
print(f"Labels batch shape: {train_labels.size()}")
imgs = train_features[0].squeeze()
label = train_labels[0]

show(imgs)

plt.savefig(f"../../assets/datasets_adrenal.png", bbox_inches='tight')
print(f"Label: {label}")
# Out:
# Feature batch shape: torch.Size([4, 1, 28, 28, 28])
# Labels batch shape: torch.Size([4, 1])
# Label: tensor([0])
