# %%
import pandas as pd
import numpy as np

# %%
benchmarks = pd.DataFrame({
        "model": ["ResNet-18 + 2.5D", "ResNet-18 + 3D", "ResNet-18 + ACS", "ResNet-50 + 2.5D", "ResNet-50 + 3D", "ResNet-50 + ACS", "auto-sklearn", "AutoKeras"],
        "acc": [0.772, 0.721, 0.754, 0.763, 0.745, 0.758, 0.802, 0.705],
        "roc_auc": [0.718, 0.827, 0.839, 0.732, 0.828, 0.828, 0.828, 0.804],
        "parameters": "Unknown",
    },
    columns=["model", "acc", "roc_auc", "parameters"]
)
benchmarks
# Out:
#               model    acc  roc_auc parameters
# 0  ResNet-18 + 2.5D  0.772    0.718    Unknown
# 1    ResNet-18 + 3D  0.721    0.827    Unknown
# 2   ResNet-18 + ACS  0.754    0.839    Unknown
# 3  ResNet-50 + 2.5D  0.763    0.732    Unknown
# 4    ResNet-50 + 3D  0.745    0.828    Unknown
# 5   ResNet-50 + ACS  0.758    0.828    Unknown
# 6      auto-sklearn  0.802    0.828    Unknown
# 7         AutoKeras  0.705    0.804    Unknown

# %%
metrics = pd.read_csv("metrics_adrenal.csv")
metrics.rename(columns={"Unnamed: 0": "model"}, inplace=True)
metrics.drop(columns=["loss"], inplace=True)

metrics[["acc", "roc_auc"]] = np.round(metrics[["acc", "roc_auc"]], 3)
metrics.sort_values("acc", ascending=False, inplace=True)

metrics = pd.concat([benchmarks, metrics], axis=0)
metrics.reset_index(drop=True, inplace=True)

metrics
# Out:
#                model    acc  roc_auc parameters
# 0   ResNet-18 + 2.5D  0.772    0.718    Unknown
# 1     ResNet-18 + 3D  0.721    0.827    Unknown
# 2    ResNet-18 + ACS  0.754    0.839    Unknown
# 3   ResNet-50 + 2.5D  0.763    0.732    Unknown
# 4     ResNet-50 + 3D  0.745    0.828    Unknown
# 5    ResNet-50 + ACS  0.758    0.828    Unknown
# 6       auto-sklearn  0.802    0.828    Unknown
# 7          AutoKeras  0.705    0.804    Unknown
# 8   MNIST3dCNNExp3N6  0.818    0.863      59405
# 9   MNIST3dCNNExp2N4  0.812    0.855      13739
# 10  MNIST3dCNNExp3N1  0.810    0.845      59405
# 11  MNIST3dCNNExp1N3  0.802    0.855      59405
# 12  MNIST3dCNNExp4N3  0.801    0.845      83751
# 13  MNIST3dCNNExp2N1  0.799    0.839      79245
# 14  MNIST3dCNNExp2N3  0.796    0.859     120205
# 15  MNIST3dCNNExp1N4  0.794    0.850      27701
# 16  MNIST3dCNNExp4N1  0.787    0.844      15655
# 17  MNIST3dLiqExp3N5  0.785    0.770      37306
# 18  MNIST3dLiqExp4N6  0.777    0.740      55627
# 19  MNIST3dCNNExp4N4  0.776    0.848      41487
# 20  MNIST3dLiqExp1N2  0.773    0.798      37265
# 21  MNIST3dLiqExp1N5  0.773    0.682      37930
# 22  MNIST3dCNNExp1N1  0.768    0.836      59405
# 23  MNIST3dLiqExp2N6  0.765    0.746      53528
# 24  MNIST3dLiqExp3N3  0.765    0.753      38065
# 25  MNIST3dLiqExp2N5  0.765    0.754      37930
# 26  MNIST3dLiqExp2N2  0.765    0.752      37265
# 27  MNIST3dLiqExp4N5  0.762    0.685      19140
# 28  MNIST3dLiqExp3N4  0.760    0.775      37265
# 29  MNIST3dLiqExp3N2  0.755    0.716     127537
# 30  MNIST3dLiqExp4N2  0.755    0.718      18475
# 31  MNIST3dLiqExp1N6  0.732    0.772      53528

# %%
metrics.to_csv("metrics_combined_adrenal.csv")
