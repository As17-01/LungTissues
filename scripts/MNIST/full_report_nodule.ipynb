# %%
import pandas as pd
import numpy as np

# %%
benchmarks = pd.DataFrame({
        "model": ["ResNet-18 + 2.5D", "ResNet-18 + 3D", "ResNet-18 + ACS", "ResNet-50 + 2.5D", "ResNet-50 + 3D", "ResNet-50 + ACS", "auto-sklearn", "AutoKeras"],
        "acc": [0.772, 0.721, 0.754, 0.763, 0.745, 0.758, 0.802, 0.705],
        "roc_auc": [0.718, 0.827, 0.839, 0.732, 0.828, 0.828, 0.828, 0.804],
        "parameters": "Unknown",
    },
    columns=["model", "acc", "roc_auc", "parameters"]
)
benchmarks
# Out:
#               model    acc  roc_auc parameters
# 0  ResNet-18 + 2.5D  0.772    0.718    Unknown
# 1    ResNet-18 + 3D  0.721    0.827    Unknown
# 2   ResNet-18 + ACS  0.754    0.839    Unknown
# 3  ResNet-50 + 2.5D  0.763    0.732    Unknown
# 4    ResNet-50 + 3D  0.745    0.828    Unknown
# 5   ResNet-50 + ACS  0.758    0.828    Unknown
# 6      auto-sklearn  0.802    0.828    Unknown
# 7         AutoKeras  0.705    0.804    Unknown

# %%
metrics = pd.read_csv("metrics_nodule.csv")
metrics.rename(columns={"Unnamed: 0": "model"}, inplace=True)
metrics.drop(columns=["loss"], inplace=True)

metrics[["acc", "roc_auc"]] = np.round(metrics[["acc", "roc_auc"]], 3)
metrics.sort_values("acc", ascending=False, inplace=True)

metrics = pd.concat([benchmarks, metrics], axis=0)
metrics.reset_index(drop=True, inplace=True)

metrics
# Out:
#                model    acc  roc_auc parameters
# 0   ResNet-18 + 2.5D  0.772    0.718    Unknown
# 1     ResNet-18 + 3D  0.721    0.827    Unknown
# 2    ResNet-18 + ACS  0.754    0.839    Unknown
# 3   ResNet-50 + 2.5D  0.763    0.732    Unknown
# 4     ResNet-50 + 3D  0.745    0.828    Unknown
# 5    ResNet-50 + ACS  0.758    0.828    Unknown
# 6       auto-sklearn  0.802    0.828    Unknown
# 7          AutoKeras  0.705    0.804    Unknown
# 8   MNIST3dCNNExp4N1  0.862    0.908      15655
# 9   MNIST3dCNNExp4N4  0.861    0.876      41487
# 10  MNIST3dLiqExp2N5  0.860    0.876      37930
# 11  MNIST3dCNNExp2N4  0.855    0.847      13739
# 12  MNIST3dCNNExp4N3  0.855    0.886      83751
# 13  MNIST3dLiqExp4N2  0.855    0.908      18475
# 14  MNIST3dLiqExp2N2  0.854    0.873      37265
# 15  MNIST3dLiqExp1N5  0.854    0.895      37930
# 16  MNIST3dLiqExp1N6  0.852    0.904      53528
# 17  MNIST3dLiqExp3N3  0.850    0.891      38065
# 18  MNIST3dCNNExp2N3  0.848    0.853     120205
# 19  MNIST3dCNNExp1N4  0.848    0.852      27701
# 20  MNIST3dLiqExp3N4  0.848    0.889      37265
# 21  MNIST3dLiqExp4N6  0.847    0.873      55627
# 22  MNIST3dCNNExp2N1  0.844    0.828      79245
# 23  MNIST3dLiqExp1N2  0.844    0.876      37265
# 24  MNIST3dCNNExp3N6  0.842    0.828      59405
# 25  MNIST3dLiqExp3N5  0.841    0.884      37306
# 26  MNIST3dLiqExp2N6  0.839    0.825      53528
# 27  MNIST3dCNNExp1N3  0.839    0.885      59405
# 28  MNIST3dCNNExp1N1  0.838    0.887      59405
# 29  MNIST3dLiqExp3N2  0.835    0.883     127537
# 30  MNIST3dLiqExp4N5  0.835    0.862      19140
# 31  MNIST3dCNNExp3N1  0.835    0.853      59405

# %%
metrics.to_csv("metrics_combined_nodule.csv")
